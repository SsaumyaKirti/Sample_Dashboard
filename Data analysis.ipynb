# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
def main():
 dataset = pd.read_csv('any data set.csv')
 dataset.head(1)
 dataset.info()

 dataset.isnull().sum()      # to check for NULL values in data and handle them 
 dataset['Email'].astype('string')  #data type on email is string type
 dataset['Email'].dtypes

 emailids(dataset) 
 Prospects(dataset) 


#check Email IDs are from gmail websites 
def emailids(x):
  counter=0
  for i in range(dataset.shape[0]):
    x=dataset["Email"][i].find("@gmail.com")
    if x >1 :
        print(dataset["Email"][i])
        counter+=1
  print ('Email Address of customer signed in with gmail',counter)

 

#check prospect customers by the condition if they spend more than 20 minutes on the platform
def Prospects(x):
  counter=0
  for i in range(dataset.shape[0]):
        if dataset["Avg. Session Length"][i] >= 35 :
          print ('Prospect''s email address',dataset["Email"][i])
          counter+=1
  print ('total count of prospect custromers',counter)


if __name__ == "__main__":
    main()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB
# riverarebecca@gmail.com
# knelson@gmail.com
# taylormason@gmail.com
# wjennings@gmail.com
# megan33@gmail.com
# jenniferbarnett@gmail.com
# joshuaodom@gmail.com
# enash@gmail.com
# christopher20@gmail.com
# gonzaleskatie@gmail.com
# william82@gmail.com
# jeffreydawson@gmail.com
# rjohns@gmail.com
# ...
